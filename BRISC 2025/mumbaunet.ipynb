# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/manifest.json
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/README.md
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/manifest.csv
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/manifest.json.sha256
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/manifest.csv.sha256
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00560_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00949_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00177_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00799_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00705_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00510_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00180_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00061_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00551_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_01000_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00301_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00151_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00403_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00348_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00829_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00735_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00183_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00228_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00704_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00707_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00743_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00226_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00834_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00141_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00857_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00932_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00998_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00920_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00276_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00184_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00225_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00242_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00830_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00234_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00457_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00215_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00458_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00741_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00044_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00386_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00759_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00233_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00886_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00379_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00205_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00836_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00295_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00194_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00120_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00495_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00924_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00779_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00943_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00316_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00708_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00278_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00397_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00493_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00995_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00322_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00885_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00950_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00709_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00252_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00103_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00775_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00981_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00065_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00178_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00812_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00429_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00431_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00543_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00309_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00100_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00195_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00822_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00490_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00971_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00996_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00711_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00101_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00032_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00289_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00923_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00391_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00555_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00096_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00038_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00085_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00860_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00227_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00202_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00420_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00875_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00968_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00739_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00471_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00839_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00519_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00338_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00384_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00986_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00752_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00942_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00975_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00070_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00399_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00329_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00381_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00046_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00408_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00231_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00198_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00792_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00430_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00135_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00762_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00058_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00088_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00876_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00090_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00959_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00439_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00079_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00009_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00251_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00905_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00127_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00236_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00930_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00483_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00318_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00423_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00745_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00537_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00504_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00235_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00525_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00877_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00407_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00548_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00823_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00530_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00193_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00188_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00129_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00909_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00817_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00706_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00378_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00285_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00502_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00520_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00344_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00422_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00360_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00507_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00455_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00904_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00832_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00557_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00185_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00805_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00244_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00319_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00851_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00732_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00035_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00784_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00060_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00075_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00534_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00506_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00755_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00333_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00246_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00336_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00928_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00861_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00747_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00701_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00109_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00524_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00055_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00744_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00169_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00898_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00369_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00299_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00518_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00176_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00985_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00229_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00051_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00310_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00214_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00291_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00167_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00887_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00774_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00969_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00870_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00793_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00758_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00232_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00092_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00454_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00976_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00528_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00367_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00883_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00769_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00345_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00716_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00343_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00535_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00978_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00815_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00824_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00339_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00723_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00282_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00133_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00801_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00466_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00849_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00492_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00207_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00938_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00713_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00134_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00516_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00175_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00961_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00469_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00191_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00826_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00965_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00897_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00294_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00772_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00220_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00398_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00093_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00018_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00958_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00853_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00415_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00918_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00850_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00934_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00940_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00780_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00460_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00240_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00161_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00156_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00912_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00837_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00224_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00880_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00056_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00307_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00005_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00999_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00124_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00447_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00475_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00770_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00249_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00914_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00128_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00328_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00008_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00907_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00731_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00123_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00771_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00368_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00212_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00308_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00715_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00149_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00334_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00062_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00789_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00783_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00097_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00868_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00189_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00067_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00054_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00796_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00290_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00840_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00992_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00726_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00279_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00881_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00797_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00287_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00966_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00487_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00064_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00456_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00342_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00137_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00703_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00255_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00081_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00154_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00740_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00765_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00296_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00002_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00913_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00028_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00394_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00871_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00727_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00719_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00936_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00749_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00410_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00550_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00131_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00738_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00781_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00355_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00247_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00736_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00463_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00718_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00030_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00091_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00514_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00293_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00209_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00915_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00730_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00440_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00083_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00119_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00412_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00325_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00552_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00094_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00114_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00172_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00505_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00476_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00416_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00003_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00382_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00450_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00300_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00753_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00558_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00388_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00335_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00925_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00766_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00192_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00284_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00526_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00474_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00979_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00437_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00997_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00468_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00082_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00522_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00434_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00357_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00138_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00722_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00786_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00365_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00954_pi_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00833_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00545_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00846_pi_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00710_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00529_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00089_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00387_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00401_me_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00238_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00022_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00140_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00196_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00272_me_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00105_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00546_me_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00795_pi_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/segmentation_task/test/images/brisc2025_test_00263_me_ax_t1.jpg
# ...
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00696_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00284_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00982_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00538_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00161_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00854_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00567_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00871_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00012_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00444_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00233_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00004_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00941_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00799_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00834_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00014_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00746_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00966_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00093_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01032_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00097_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00912_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00206_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00195_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00881_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00565_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00251_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00867_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00088_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00544_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00564_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00393_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00178_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00842_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00758_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00030_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01031_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00416_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00190_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00131_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00468_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00603_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00632_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00317_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00697_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00995_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00175_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00312_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01103_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00951_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00968_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00500_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01093_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00146_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00839_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00700_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00623_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00894_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00897_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00973_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01040_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00119_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00348_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00835_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00421_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00601_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01081_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00691_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00192_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00809_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00815_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00595_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00476_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00520_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01145_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00993_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00857_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00709_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00956_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01135_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00267_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00617_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00803_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00003_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01018_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00479_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00465_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01073_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00311_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00639_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01123_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00893_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00911_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00096_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00320_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00935_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00800_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00367_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00092_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00270_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00152_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00078_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00460_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00475_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00327_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00732_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00374_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00765_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00591_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00583_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00558_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00653_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00087_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00038_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00622_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00398_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00967_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00025_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00399_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00466_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00720_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01075_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01010_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00503_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00125_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00625_gl_co_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_01122_gl_sa_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00165_gl_ax_t1.jpg
# /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train/glioma/brisc2025_train_00135_gl_ax_t1.jpg

# %%
# !pip install torch==2.3.1 torchvision==0.18.1 --index-url https://download.pytorch.org/whl/cu118 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.6/839.6 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 77.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 99.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.5/728.5 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 MB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.3.1+cu118 which is incompatible.

# %%
import subprocess
subprocess.run(["pip", "install", "segmentation-models-pytorch", "einops", "-q"], check=True)

import os, glob, random
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.functional as TF

torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

BASE_PATH     = "/kaggle/input/datasets/briscdataset/brisc2025/brisc2025"
TRAIN_IMG_DIR = os.path.join(BASE_PATH, "segmentation_task/train/images")
TRAIN_MSK_DIR = os.path.join(BASE_PATH, "segmentation_task/train/masks")
TEST_IMG_DIR  = os.path.join(BASE_PATH, "segmentation_task/test/images")
TEST_MSK_DIR  = os.path.join(BASE_PATH, "segmentation_task/test/masks")

CFG = dict(
    img_size     = 256,
    batch_size   = 8,
    lr           = 1e-4,
    weight_decay = 1e-5,
    epochs       = 80,
    patience     = 10,
    val_split    = 0.15,
    device       = "cuda" if torch.cuda.is_available() else "cpu",
)
print(f"Device : {CFG['device']}")
print(f"PyTorch: {torch.__version__}")


class BRISCDataset(Dataset):
    def __init__(self, img_paths, mask_paths, img_size=256, augment=False):
        self.img_paths  = img_paths
        self.mask_paths = mask_paths
        self.img_size   = img_size
        self.augment    = augment

    def __len__(self):
        return len(self.img_paths)

    def _load(self, path, gray=False):
        img = Image.open(path).convert("L" if gray else "RGB")
        return img.resize((self.img_size, self.img_size), Image.BILINEAR)

    def __getitem__(self, idx):
        img  = self._load(self.img_paths[idx])
        mask = self._load(self.mask_paths[idx], gray=True)
        if self.augment:
            if random.random() > 0.5: img, mask = TF.hflip(img), TF.hflip(mask)
            if random.random() > 0.5: img, mask = TF.vflip(img), TF.vflip(mask)
            angle = random.choice([0, 90, 180, 270])
            if angle:
                img  = TF.rotate(img,  angle)
                mask = TF.rotate(mask, angle)
            img = TF.adjust_brightness(img, random.uniform(0.8, 1.2))
            img = TF.adjust_contrast(img,   random.uniform(0.8, 1.2))
        img  = TF.to_tensor(img)
        img  = TF.normalize(img, [0.5]*3, [0.5]*3)
        mask = TF.to_tensor(mask)
        mask = (mask > 0.5).float()
        return img, mask


def get_loaders():
    img_paths  = sorted(glob.glob(os.path.join(TRAIN_IMG_DIR, "*")))
    mask_paths = sorted(glob.glob(os.path.join(TRAIN_MSK_DIR, "*")))
    assert len(img_paths) > 0, f"No images found at {TRAIN_IMG_DIR}"
    assert len(img_paths) == len(mask_paths), "Image/mask count mismatch!"
    print(f"Total train samples: {len(img_paths)}")
    idx = list(range(len(img_paths)))
    random.shuffle(idx)
    n_val = int(len(idx) * CFG["val_split"])
    t_idx, v_idx = idx[n_val:], idx[:n_val]
    train_ds = BRISCDataset([img_paths[i] for i in t_idx],
                             [mask_paths[i] for i in t_idx],
                             CFG["img_size"], augment=True)
    val_ds   = BRISCDataset([img_paths[i] for i in v_idx],
                             [mask_paths[i] for i in v_idx],
                             CFG["img_size"], augment=False)
    train_loader = DataLoader(train_ds, batch_size=CFG["batch_size"],
                              shuffle=True,  num_workers=2, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=CFG["batch_size"],
                              shuffle=False, num_workers=2, pin_memory=True)
    print(f"Train: {len(train_ds)} | Val: {len(val_ds)}")
    return train_loader, val_loader


def get_test_loader():
    img_paths  = sorted(glob.glob(os.path.join(TEST_IMG_DIR, "*")))
    mask_paths = sorted(glob.glob(os.path.join(TEST_MSK_DIR, "*")))
    assert len(img_paths) > 0, f"No test images found at {TEST_IMG_DIR}"
    print(f"Total test samples: {len(img_paths)}")
    test_ds = BRISCDataset(img_paths, mask_paths, CFG["img_size"], augment=False)
    return DataLoader(test_ds, batch_size=CFG["batch_size"],
                      shuffle=False, num_workers=2, pin_memory=True)


class DiceBCELoss(nn.Module):
    def __init__(self, smooth=1.0):
        super().__init__()
        self.smooth = smooth
        self.bce    = nn.BCEWithLogitsLoss()

    def forward(self, logits, targets):
        bce   = self.bce(logits, targets)
        prob  = torch.sigmoid(logits)
        inter = (prob * targets).sum(dim=(2, 3))
        dice  = 1 - (2*inter + self.smooth) / (
                    prob.sum(dim=(2,3)) + targets.sum(dim=(2,3)) + self.smooth)
        return 0.5 * dice.mean() + 0.5 * bce


def compute_metrics(logits, masks, thresh=0.5):
    preds = (torch.sigmoid(logits) > thresh).float()
    inter = (preds * masks).sum()
    dice  = (2*inter + 1) / (preds.sum() + masks.sum() + 1)
    iou   = (inter + 1)   / (preds.sum() + masks.sum() - inter + 1)
    acc   = (preds == masks).float().mean()
    tp    = ((preds==1)&(masks==1)).sum().float()
    tn    = ((preds==0)&(masks==0)).sum().float()
    fp    = ((preds==1)&(masks==0)).sum().float()
    fn    = ((preds==0)&(masks==1)).sum().float()
    prec  = tp / (tp + fp + 1e-7)
    rec   = tp / (tp + fn + 1e-7)
    spec  = tn / (tn + fp + 1e-7)
    pixel_acc = (tp + tn) / (tp + tn + fp + fn + 1e-7)
    return dice.item(), iou.item(), acc.item(), prec.item(), rec.item(), spec.item(), pixel_acc.item()


def evaluate_split(model, loader, device, split_name):
    model.eval()
    criterion = DiceBCELoss()
    total_loss = 0.0
    v_dice = v_iou = v_acc = v_prec = v_rec = v_spec = v_pix = 0.0
    with torch.no_grad():
        for imgs, masks in loader:
            imgs, masks = imgs.to(device), masks.to(device)
            out = model(imgs)
            if out.shape[-2:] != masks.shape[-2:]:
                out = F.interpolate(out, size=masks.shape[-2:], mode='bilinear', align_corners=False)
            total_loss += criterion(out, masks).item()
            d, i, a, p, r, s, px = compute_metrics(out, masks)
            v_dice += d; v_iou += i; v_acc += a
            v_prec += p; v_rec += r; v_spec += s; v_pix += px
    n = len(loader)
    print(f"\n{'='*60}")
    print(f"  {split_name} EVALUATION")
    print(f"{'='*60}")
    print(f"  Loss       : {total_loss/n:.4f}")
    print(f"  Dice       : {v_dice/n*100:.2f}%")
    print(f"  IoU        : {v_iou/n*100:.2f}%")
    print(f"  Pixel Acc  : {v_pix/n*100:.2f}%")
    print(f"  Accuracy   : {v_acc/n*100:.2f}%")
    print(f"  Precision  : {v_prec/n*100:.2f}%")
    print(f"  Recall     : {v_rec/n*100:.2f}%")
    print(f"  Specificity: {v_spec/n*100:.2f}%")
    print(f"{'='*60}")
    return v_dice/n, v_iou/n



def plot_history(history, model_name):
    epochs = range(1, len(history["train_loss"]) + 1)
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Left plot — Model Accuracy
    axes[0].plot(epochs, history["train_acc"], color='steelblue',  linewidth=1.5, label="Training Accuracy")
    axes[0].plot(epochs, history["val_acc"],   color='darkorange', linewidth=1.5, label="Validation Accuracy")
    axes[0].set_title("Model Accuracy")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Accuracy")
    axes[0].legend(loc="lower right")
    axes[0].grid(True, alpha=0.3)

    # Right plot — Model Loss
    axes[1].plot(epochs, history["train_loss"], color='steelblue',  linewidth=1.5, label="Training Loss")
    axes[1].plot(epochs, history["val_loss"],   color='darkorange', linewidth=1.5, label="Validation Loss")
    axes[1].set_title("Model Loss")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Loss")
    axes[1].legend(loc="upper right")
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"/kaggle/working/{model_name}_history.png", dpi=150)
    plt.show()
    print(f"Plot saved to /kaggle/working/{model_name}_history.png")



class MambaBlock(nn.Module):
    def __init__(self, ch):
        super().__init__()
        self.norm = nn.LayerNorm(ch)
        self.proj = nn.Linear(ch, ch)
        self.gate = nn.Linear(ch, ch)
        self.out  = nn.Linear(ch, ch)
        self.act  = nn.SiLU()

    def forward(self, x):
        B, C, H, W = x.shape
        t = x.flatten(2).transpose(1, 2)
        n = self.norm(t)
        t = t + self.out(self.act(self.proj(n)) * torch.sigmoid(self.gate(n)))
        return t.transpose(1, 2).reshape(B, C, H, W)


class ConvBNReLU(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.block(x)


class MambaUNet(nn.Module):
    def __init__(self, in_ch=3, num_classes=1, base=64):
        super().__init__()
        f = [base, base*2, base*4, base*8, base*16]

        self.enc1 = ConvBNReLU(in_ch, f[0])
        self.enc2 = ConvBNReLU(f[0],  f[1])
        self.enc3 = ConvBNReLU(f[1],  f[2])
        self.enc4 = ConvBNReLU(f[2],  f[3])
        self.pool = nn.MaxPool2d(2)

        self.bottleneck = nn.Sequential(
            ConvBNReLU(f[3], f[4]),
            MambaBlock(f[4]),
        )

        self.up4  = nn.ConvTranspose2d(f[4], f[3], 2, stride=2)
        self.dec4 = ConvBNReLU(f[3]*2, f[3])
        self.mam4 = MambaBlock(f[3])

        self.up3  = nn.ConvTranspose2d(f[3], f[2], 2, stride=2)
        self.dec3 = ConvBNReLU(f[2]*2, f[2])
        self.mam3 = MambaBlock(f[2])

        self.up2  = nn.ConvTranspose2d(f[2], f[1], 2, stride=2)
        self.dec2 = ConvBNReLU(f[1]*2, f[1])
        self.mam2 = MambaBlock(f[1])

        self.up1  = nn.ConvTranspose2d(f[1], f[0], 2, stride=2)
        self.dec1 = ConvBNReLU(f[0]*2, f[0])

        self.dropout = nn.Dropout2d(0.3)
        self.head    = nn.Conv2d(f[0], num_classes, 1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        b  = self.bottleneck(self.pool(e4))
        d4 = self.mam4(self.dec4(torch.cat([self.up4(b),  e4], 1)))
        d3 = self.mam3(self.dec3(torch.cat([self.up3(d4), e3], 1)))
        d2 = self.mam2(self.dec2(torch.cat([self.up2(d3), e2], 1)))
        d1 =           self.dec1(torch.cat([self.up1(d2), e1], 1))
        return self.head(self.dropout(d1))


def train_model(model, model_name):
    device = CFG["device"]
    model  = model.to(device)

    train_loader, val_loader = get_loaders()
    criterion = DiceBCELoss()
    optimizer = torch.optim.AdamW(model.parameters(),
                                  lr=CFG["lr"],
                                  weight_decay=CFG["weight_decay"])
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10)

    best_dice, no_improve = 0.0, 0
    best_weights = None

    # Added train_acc, val_loss to history; removed val_dice, val_iou, val_pixel_acc
    history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n{'='*60}")
    print(f"  Model  : {model_name}")
    print(f"  Params : {n_params/1e6:.2f}M")
    print(f"  Device : {device}")
    print(f"{'='*60}")

    for epoch in range(1, CFG["epochs"] + 1):

        # ── Training loop: now also accumulates train accuracy ──
        model.train()
        t_loss = 0.0
        t_acc  = 0.0
        for imgs, masks in train_loader:
            imgs, masks = imgs.to(device), masks.to(device)
            optimizer.zero_grad()
            out = model(imgs)
            if out.shape[-2:] != masks.shape[-2:]:
                out = F.interpolate(out, size=masks.shape[-2:], mode='bilinear', align_corners=False)
            loss = criterion(out, masks)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            t_loss += loss.item()
            _, _, a, _, _, _, _ = compute_metrics(out, masks)
            t_acc += a
        t_loss /= len(train_loader)
        t_acc  /= len(train_loader)

        # ── Validation loop: now also accumulates val loss ──
        model.eval()
        v_loss = 0.0
        v_dice = v_iou = v_acc = v_prec = v_rec = v_spec = v_pix = 0.0
        with torch.no_grad():
            for imgs, masks in val_loader:
                imgs, masks = imgs.to(device), masks.to(device)
                out = model(imgs)
                if out.shape[-2:] != masks.shape[-2:]:
                    out = F.interpolate(out, size=masks.shape[-2:], mode='bilinear', align_corners=False)
                v_loss += criterion(out, masks).item()
                d, i, a, p, r, s, px = compute_metrics(out, masks)
                v_dice += d; v_iou += i; v_acc += a
                v_prec += p; v_rec += r; v_spec += s; v_pix += px

        n = len(val_loader)
        v_loss /= n
        v_dice /= n; v_iou /= n; v_acc /= n
        v_prec /= n; v_rec /= n; v_spec /= n; v_pix /= n

        scheduler.step()
        history["train_loss"].append(t_loss)
        history["val_loss"].append(v_loss)
        history["train_acc"].append(t_acc)
        history["val_acc"].append(v_acc)

        if epoch % 10 == 0 or epoch == 1:
            print(f"  Ep {epoch:03d} | Loss:{t_loss:.4f} | "
                  f"Dice:{v_dice:.4f} | IoU:{v_iou:.4f} | "
                  f"PixAcc:{v_pix:.4f} | Acc:{v_acc:.4f} | "
                  f"Prec:{v_prec:.4f} | Rec:{v_rec:.4f} | Spec:{v_spec:.4f}")

        if v_dice > best_dice:
            best_dice    = v_dice
            best_weights = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            no_improve   = 0
        else:
            no_improve += 1
            if no_improve >= CFG["patience"]:
                print(f"  Early stop at epoch {epoch}.")
                break

    model.load_state_dict(best_weights)

    print(f"\n{'='*60}")
    print(f"  {model_name} TRAINING COMPLETE")
    print(f"  Best Val Dice : {best_dice*100:.2f}%")
    print(f"{'='*60}")

    plot_history(history, model_name)

    print("\n--- Evaluating on Train Set ---")
    train_loader_eval, _ = get_loaders()
    evaluate_split(model, train_loader_eval, device, "TRAIN")

    print("\n--- Evaluating on Validation Set ---")
    _, val_loader_eval = get_loaders()
    evaluate_split(model, val_loader_eval, device, "VALIDATION")

    print("\n--- Evaluating on Test Set ---")
    test_loader = get_test_loader()
    test_dice, test_iou = evaluate_split(model, test_loader, device, "TEST")

    return model, history, best_dice, test_iou



model_mamba = MambaUNet(in_ch=3, num_classes=1, base=64)
model_mamba, history_mamba, dice_mamba, iou_mamba = train_model(model_mamba, "MambaUNet")
print(f"\n[FINAL RESULT] MambaUNet → Val Dice: {dice_mamba*100:.2f}% | Test IoU: {iou_mamba*100:.2f}%")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.6 MB/s eta 0:00:00
# Device : cuda
# PyTorch: 2.3.1+cu118
# Total train samples: 3933
# Train: 3344 | Val: 589
#
# ============================================================
#   Model  : MambaUNet
#   Params : 35.23M
#   Device : cuda
# ============================================================
#   Ep 001 | Loss:0.6349 | Dice:0.4604 | IoU:0.3075 | PixAcc:0.9820 | Acc:0.9820 | Prec:0.4413 | Rec:0.5069 | Spec:0.9898
#   Ep 010 | Loss:0.1723 | Dice:0.8524 | IoU:0.7495 | PixAcc:0.9953 | Acc:0.9953 | Prec:0.8526 | Rec:0.8617 | Spec:0.9975
#   Ep 020 | Loss:0.0999 | Dice:0.8666 | IoU:0.7724 | PixAcc:0.9958 | Acc:0.9958 | Prec:0.8780 | Rec:0.8634 | Spec:0.9981
#   Ep 030 | Loss:0.0850 | Dice:0.8752 | IoU:0.7843 | PixAcc:0.9961 | Acc:0.9961 | Prec:0.8817 | Rec:0.8759 | Spec:0.9981
#   Ep 040 | Loss:0.0780 | Dice:0.8848 | IoU:0.7981 | PixAcc:0.9963 | Acc:0.9963 | Prec:0.8789 | Rec:0.8967 | Spec:0.9980
#   Early stop at epoch 49.
#
# ============================================================
#   MambaUNet TRAINING COMPLETE
#   Best Val Dice : 88.58%
# ============================================================
# Plot saved to /kaggle/working/MambaUNet_history.png
#
# --- Evaluating on Train Set ---
# Total train samples: 3933
# Train: 3344 | Val: 589
#
# ============================================================
#   TRAIN EVALUATION
# ============================================================
#   Loss       : 0.0774
#   Dice       : 88.26%
#   IoU        : 79.59%
#   Pixel Acc  : 99.62%
#   Accuracy   : 99.62%
#   Precision  : 89.91%
#   Recall     : 87.37%
#   Specificity: 99.83%
# ============================================================
#
# --- Evaluating on Validation Set ---
# Total train samples: 3933
# Train: 3344 | Val: 589
#
# ============================================================
#   VALIDATION EVALUATION
# ============================================================
#   Loss       : 0.0742
#   Dice       : 89.16%
#   IoU        : 80.98%
#   Pixel Acc  : 99.68%
#   Accuracy   : 99.68%
#   Precision  : 90.18%
#   Recall     : 88.53%
#   Specificity: 99.85%
# ============================================================
#
# --- Evaluating on Test Set ---
# Total test samples: 860
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   Loss       : 0.0841
#   Dice       : 87.22%
#   IoU        : 78.49%
#   Pixel Acc  : 99.55%
#   Accuracy   : 99.55%
#   Precision  : 87.31%
#   Recall     : 87.96%
#   Specificity: 99.78%
# ============================================================
#
# [FINAL RESULT] MambaUNet → Val Dice: 88.58% | Test IoU: 78.49%
